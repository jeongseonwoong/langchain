# %% [markdown]
# 1. langchain-anthropic 라이브러리 설치

# %%
# %pip install langchain-anthropic

# %% [markdown]
# 2. 환경변수 가져오기기

# %%
from dotenv import load_dotenv

load_dotenv()

# %%
from langchain_anthropic import ChatAnthropic

llm = ChatAnthropic(model = "claude-haiku-4-5")

# %%
ai_message = llm.invoke("정선웅은 최강인가요?")

# %%
ai_message.content
# Out:
# '정선웅이 누구인지, 그리고 어떤 분야에서 "최강"인지에 대해 더 구체적인 정보가 필요합니다.\n\n혹시 다음 중 하나를 의미하시나요?\n\n- **특정 스포츠 선수**: 축구, 격투기, e스포츠 등\n- **유명인이나 인물**: 특정 분야의 전문가\n- **게임이나 웹소설의 캐릭터**\n- **기타 맥락**\n\n더 자세히 설명해주시면 더 정확한 답변을 드릴 수 있습니다!'
