# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="qwen2.5:7b")

llm.invoke("안녕하세요")
# Out:
# AIMessage(content='안녕하세요! 어떻게 도와드릴 수 있을까요?', additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b', 'created_at': '2026-04-13T12:53:41.939074515Z', 'done': True, 'done_reason': 'stop', 'total_duration': 399203725, 'load_duration': 115935919, 'prompt_eval_count': 32, 'prompt_eval_duration': 46663879, 'eval_count': 14, 'eval_duration': 217973008, 'logprobs': None, 'model_name': 'qwen2.5:7b', 'model_provider': 'ollama'}, id='lc_run--019d86e7-a622-7240-8713-fd2136751b91-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 14, 'total_tokens': 46})

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True
